# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import json
# import os
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
def Train_Test_XY_normalize_PCA(TrainX, TrainY, PCA_n = 40):
    
    # normalize data
    scaler_new = StandardScaler()
    scaler_new.fit(TrainX)
    X_train_scale = scaler_new.transform(TrainX)
    print(f'X shape {X_train_scale.shape}')
    
    # dimension reduction
    TrainX_PCA = Train_Test_XY_PCA(X_train_scale, PCA_n = PCA_n)
    print(f'X shape {TrainX_PCA.shape}')
    
    X_train, X_test, y_train, y_test = train_test_split(TrainX_PCA,TrainY,
                                                       test_size=.2,
                                                       shuffle=True,
                                                       random_state=2020,
                                                       stratify=TrainY)
    return X_train, X_test, y_train, y_test

# %%
def Train_Test_XY_PCA(TrainX, PCA_n = 40):
    pca = PCA(n_components=PCA_n)
    pca.fit(TrainX)
    TrainX = pca.transform(TrainX)
    print(f'PCA accuracy {np.sum(pca.explained_variance_ratio_)}')
    return TrainX

# %%
def NN_prototype(TrainX, TrainY, layers, PCA_n = 40):
    X_train, X_test, y_train, y_test = Train_Test_XY_normalize_PCA(TrainX, TrainY, PCA_n = PCA_n)
    
    print(f'mean of one of the features {np.mean(X_train[:,3])}')
    print(f'var of one of the features {np.var(X_train[:,3])}')
    
    X_train_train, X_val, y_train_train, y_val = train_test_split(X_train,
                                                                  y_train,
                                                                  test_size=.2,
                                                                  shuffle=True,
                                                                  random_state=2021,
                                                                  stratify=y_train)

    accuracy_Tr = []; accuracy_V = []
    for l in layers:
        print(f'Working with structure {l}')
        mlp = MLPClassifier(hidden_layer_sizes=l, max_iter=5000)
        mlp.fit(X_train_train, y_train_train)
        a_train = np.round(100*accuracy_score(y_train_train, mlp.predict(X_train_train)),2)
        a_valid = np.round(100*accuracy_score(y_val, mlp.predict(X_val)),2)
        print(f"training accuracy is {a_train}, vaidation accuracy is {a_valid}.")
        print(f'home win rate (validation set) = {sum(mlp.predict(X_val))/len(mlp.predict(X_val))}')
        print()
        accuracy_Tr.append(a_train); accuracy_V.append(a_valid)
    return accuracy_Tr, accuracy_V

# %% [markdown]
# # Read training X and training Y data

# %%
g_list = np.array([0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1])
filename = str(20142021)+'_'+str(0.9)+'.csv'

# %%
Traindf = pd.read_csv(filename)
Traindf = Traindf.dropna()
columns_name = Traindf.columns
TrainX_array = Traindf[columns_name[:-1]].to_numpy()
TrainY_array = Traindf[columns_name[-1]].to_numpy()

# %% [markdown]
# home wins are smaller than away wins

# %%
sum(TrainY_array)/len(TrainY_array)
# Out:
# 0.44613374510036824

# %% [markdown]
# # simple NN model

# %%
see_column = np.array(['AvAge', 'W/GP', 'P/GP', 'W', 'PTS', 'GF/G', 'GA/G',
                       'SRS', 'SOS', 'PP%', 'PPA'])

column_home = np.array([i+'_H' for i in see_column])
column_away = np.array([i+'_A' for i in see_column])

column_name = np.concatenate((column_home,column_away))
column_name = np.concatenate((column_name,['class']))

# %%
# layers = [(10,), (10, 20), (10, 20, 10)]
layers = [(5,), (5, 10), (5, 10, 5)]

# %%
for g in g_list:
    print('---------------------')
    print(f'------g = {g}--------')
    filename = str(20142021)+'_'+str(g)+'.csv'
    Traindf = pd.read_csv(filename)[column_name]
    Traindf = Traindf.dropna()
    columns_name = Traindf.columns
    TrainX_array = Traindf[columns_name[:-1]].to_numpy()
    TrainY_array = Traindf[columns_name[-1]].to_numpy()
    
    NN_prototype(TrainX_array, TrainY_array, layers, PCA_n = 15)
    print()
# Out:
# ---------------------
# ------g = 0.9--------
# X shape (8683, 22)
# PCA accuracy 0.9980929238903969
# X shape (8683, 15)
# mean of one of the features 0.007808411611065889
# var of one of the features 1.1521589789635702
# Working with structure (5,)
# training accuracy is 57.16, vaidation accuracy is 55.04.
# home win rate (validation set) = 0.24676258992805755
#
# Working with structure (5, 10)
# training accuracy is 58.03, vaidation accuracy is 53.74.
# home win rate (validation set) = 0.3302158273381295
#
# Working with structure (5, 10, 5)
# training accuracy is 58.44, vaidation accuracy is 54.96.
# home win rate (validation set) = 0.20719424460431654
#
#
# ---------------------
# ------g = 0.8--------
# X shape (8683, 22)
# PCA accuracy 0.9981013101611644
# X shape (8683, 15)
# mean of one of the features -0.007996413045609512
# var of one of the features 1.1514537619557137
# Working with structure (5,)
# training accuracy is 57.24, vaidation accuracy is 55.18.
# home win rate (validation set) = 0.23237410071942446
#
# Working with structure (5, 10)
# training accuracy is 57.47, vaidation accuracy is 54.17.
# home win rate (validation set) = 0.3129496402877698
#
# Working with structure (5, 10, 5)
# training accuracy is 57.88, vaidation accuracy is 55.25.
# home win rate (validation set) = 0.15827338129496402
#
#
# ---------------------
# ------g = 0.7--------
# X shape (8683, 22)
# PCA accuracy 0.9980576796183694
# X shape (8683, 15)
# mean of one of the features -0.007906516199102195
# var of one of the features 1.150073095862186
# Working with structure (5,)
# training accuracy is 57.74, vaidation accuracy is 54.96.
# home win rate (validation set) = 0.2733812949640288
#
# Working with structure (5, 10)
# training accuracy is 58.98, vaidation accuracy is 54.75.
# home win rate (validation set) = 0.32302158273381293
#
# Working with structure (5, 10, 5)
# training accuracy is 59.36, vaidation accuracy is 52.66.
# home win rate (validation set) = 0.37841726618705035
#
#
# ---------------------
# ------g = 0.6--------
# X shape (8683, 22)
# PCA accuracy 0.9979639608417306
# X shape (8683, 15)
# mean of one of the features -0.00754892569608272
# var of one of the features 1.1495071324481334
# Working with structure (5,)
# training accuracy is 57.54, vaidation accuracy is 54.24.
# home win rate (validation set) = 0.31654676258992803
#
# Working with structure (5, 10)
# training accuracy is 58.12, vaidation accuracy is 56.69.
# home win rate (validation set) = 0.22446043165467625
#
# Working with structure (5, 10, 5)
# training accuracy is 58.98, vaidation accuracy is 54.53.
# home win rate (validation set) = 0.31510791366906477
#
#
# ---------------------
# ------g = 0.5--------
# X shape (8683, 22)
# PCA accuracy 0.9978298415205143
# X shape (8683, 15)
# mean of one of the features -0.006994665793459557
# var of one of the features 1.1514530124975566
# Working with structure (5,)
# training accuracy is 57.58, vaidation accuracy is 55.76.
# home win rate (validation set) = 0.23525179856115108
#
# Working with structure (5, 10)
# training accuracy is 59.05, vaidation accuracy is 55.25.
# home win rate (validation set) = 0.31798561151079136
#
# Working with structure (5, 10, 5)
# training accuracy is 60.19, vaidation accuracy is 55.76.
# home win rate (validation set) = 0.3143884892086331
#
#
# ---------------------
# ------g = 0.4--------
# X shape (8683, 22)
# PCA accuracy 0.9976675297314659
# X shape (8683, 15)
# mean of one of the features -0.006337419444319495
# var of one of the features 1.156993008305156
# Working with structure (5,)
# training accuracy is 57.72, vaidation accuracy is 54.32.
# home win rate (validation set) = 0.2884892086330935
#
# Working with structure (5, 10)
# training accuracy is 58.1, vaidation accuracy is 54.68.
# home win rate (validation set) = 0.3064748201438849
#
# Working with structure (5, 10, 5)
# training accuracy is 57.78, vaidation accuracy is 54.75.
# home win rate (validation set) = 0.1906474820143885
#
#
# ---------------------
# ------g = 0.3--------
# X shape (8683, 22)
# PCA accuracy 0.9974870792795668
# X shape (8683, 15)
# mean of one of the features -0.005653126215246115
# var of one of the features 1.1662012503221673
# Working with structure (5,)
# training accuracy is 57.6, vaidation accuracy is 55.61.
# home win rate (validation set) = 0.239568345323741
#
# Working with structure (5, 10)
# training accuracy is 58.59, vaidation accuracy is 53.81.
# home win rate (validation set) = 0.28633093525179854
#
# Working with structure (5, 10, 5)
# training accuracy is 59.85, vaidation accuracy is 53.53.
# home win rate (validation set) = 0.3410071942446043
#
#
# ---------------------
# ------g = 0.2--------
# X shape (8683, 22)
# PCA accuracy 0.9972949057169285
# X shape (8683, 15)
# mean of one of the features -0.004990413651497333
# var of one of the features 1.1781150252804098
# Working with structure (5,)
# training accuracy is 57.97, vaidation accuracy is 56.04.
# home win rate (validation set) = 0.27697841726618705
#
# Working with structure (5, 10)
# training accuracy is 58.68, vaidation accuracy is 52.37.
# home win rate (validation set) = 0.30071942446043165
#
# Working with structure (5, 10, 5)
# training accuracy is 58.78, vaidation accuracy is 55.4.
# home win rate (validation set) = 0.28633093525179854
#
#
# ---------------------
# ------g = 0.1--------
# X shape (8683, 22)
# PCA accuracy 0.9970958747739207
# X shape (8683, 15)
# mean of one of the features -0.004385632447266906
# var of one of the features 1.1909052416554524
# Working with structure (5,)
# training accuracy is 57.16, vaidation accuracy is 55.68.
# home win rate (validation set) = 0.2316546762589928
#
# Working with structure (5, 10)
# training accuracy is 58.26, vaidation accuracy is 52.52.
# home win rate (validation set) = 0.2633093525179856
#
# Working with structure (5, 10, 5)
# training accuracy is 59.5, vaidation accuracy is 52.81.
# home win rate (validation set) = 0.30071942446043165
